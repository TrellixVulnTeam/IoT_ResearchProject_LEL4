# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---

# %% [markdown]
# ## The Activities Data
# ### Importing the Activities Data
# The file `S1Activities.csv` contains a tabulated summary of Heading, Category, Subcategory and a corresponding code.

# %%
dsActivities = pd.read_csv('S1Activities.csv', index_col = None)    # Importing the dataset

# %%
dsActivities.head(n=10)                                             # Checking the dataset
# Out:
#               Heading                 Category        Subcategory  Code
# 0  Employment related  Employment work at home       Work at home     1
# 1  Employment related        Travel employment  Going out to work     5
# 2      Personal needs                   Eating             Eating    10
# 3      Personal needs         Personal hygiene          Toileting    15
# 4      Personal needs         Personal hygiene            Bathing    20
# 5      Personal needs         Personal hygiene           Grooming    25
# 6      Personal needs         Personal hygiene           Dressing    30
# 7      Personal needs         Personal hygiene      Washing hands    35
# 8      Personal needs         Personal medical  Taking medication    40
# 9      Personal needs                 Sleeping           Sleeping    45

# %%
len(dsActivities)
# Out:
# 33

# %% [markdown]
# At this time, the activities data will not be subject to preprocessing.

# %% [markdown]
# ## The Sensor Data
# ### Importing Sensor Data
# The file `S1sensors.csv` contains a tabulated values for sensor ID (numeric), room and sensor type.

# %%
dsS1Sensors = pd.read_csv('S1sensors.csv',                    # Importing the dataset
                          index_col = None, header = None)

# %%
dsS1Sensors.head(n=5)                                         # Checking the dataset
# Out:
#      0         1              2
# 0  100  Bathroom  Toilet Flush
# 1  101  Bathroom   Light switch
# 2  104     Foyer   Light switch
# 3  105   Kitchen   Light switch
# 4  106   Kitchen         Burner

# %%
len(dsS1Sensors)                                      # Checking the length of dsS1Sensors
# Out:
# 76

# %% [markdown]
# ### Preprocessing the Sensor Data
# Column [1] & Column [2] of the sensor data will be concatenated, whitespace will be removed, all text will be cast to lowercase and a final whitespace strip will be performed.

# %%
temp1 = dsS1Sensors[1] + '_' + dsS1Sensors[2]   # Creating a new vector of concatenated column 1 & 2
temp2 = temp1.str.replace(" ", "")              # Removing whitespace between strings
temp3 = temp2.str.lower()                       # Changing all text to lowercase
temp4 = temp3.str.strip()                       # Striping any remaining whitespace
dsS1Sensors[3] = temp4                          # Adding the precessed vector back into the dataset
dsS1Sensors.rename(columns={0:'subActNum', 
                            1:'room',
                            2:'activity',
                            3:'concat',
                            4:'energyReq'}, 
                   inplace=True)

# %%
dsS1Sensors.head(n=6)                           # Checking the resultant dataset
# Out:
#    subActNum         room       activity                  concat
# 0        100     Bathroom  Toilet Flush     bathroom_toiletflush
# 1        101     Bathroom   Light switch    bathroom_lightswitch
# 2        104        Foyer   Light switch       foyer_lightswitch
# 3        105      Kitchen   Light switch     kitchen_lightswitch
# 4        106      Kitchen         Burner          kitchen_burner
# 5        107  Living room   Light switch  livingroom_lightswitch

# %% [markdown]
# <p style='text-align: justify;'>
# Each row needs to be inspected manually to determine if the activity requires electricity. This can only be done initially by manual inspection.
# </p>

# %% [markdown]
# <p style='text-align: justify;'>
# </p>

# %%
def showUniqueValues(list1):                 # Function to get unique values 
    unique_list = []                         # Intilize a null list 
    
    for x in list1:                          # Traverse for all elements 
        if x not in unique_list:             # Check if exists in unique_list or not 
            unique_list.append(x)            # Append to unique_list
    
    for x in unique_list:                    # Print list 
        print(x)

# %%
showUniqueValues(dsS1Sensors.iloc[:,3])   # Pass the concacenated sensor list to unique
# Out:
# bathroom_toiletflush
# bathroom_lightswitch
# foyer_lightswitch
# kitchen_lightswitch
# kitchen_burner
# livingroom_lightswitch
# bedroom_lightswitch
# porch_lightswitch
# kitchen_coffeemachine
# kitchen_drawer
# kitchen_refrigerator
# kitchen_oven
# bathroom_door
# kitchen_toaster
# kitchen_cabinet
# kitchen_window
# kitchen_freezer
# bedroom_jewelrybox
# foyer_door
# kitchen_door
# kitchen_washingmachine
# kitchen_microwave
# kitchen_cereal
# bedroom_drawer
# livingroom_dvd
# bathroom_medicinecabinet
# kitchen_containers
# bedroom_lamp
# bathroom_cabinet
# bathroom_sinkfaucet-hot
# kitchen_dishwasher
# livingroom_lamp
# foyer_closet
# office/study_drawer
# bedroom_window
# bathroom_sinkfaucet-cold
# kitchen_laundrydryer
# office/study_lightswitch
# bathroom_showerfaucet
# bathroom_exhaustfan
# kitchen_garbagedisposal

# %%
a = dsS1Sensors.iloc[:,3]
specialChar = '/'
reqElectricity = 'ligh|burn|mach|toas|freez|dvd|lamp|washer|dry|exh|disp|frig|oven|hot|micro'
b = a.str.contains(reqElectricity, regex = True)
c = a.str.contains(specialChar, regex = True)
dsS1Sensors['reqElectricity'] = b
dsS1Sensors['specialChar'] = c

# %%
# List all characters
def split(word): 
    return [char for char in word]

split(dsS1Sensors['concat'][0])
# Out:
# ['b',
#  'a',
#  't',
#  'h',
#  'r',
#  'o',
#  'o',
#  'm',
#  '_',
#  't',
#  'o',
#  'i',
#  'l',
#  'e',
#  't',
#  'f',
#  'l',
#  'u',
#  's',
#  'h']

# %%
forwardSlashFilter = dsS1Sensors['concat'].str.contains('/', regex = True)
# Filter for true

# %%
dsS1Sensors[0:25]
# Out:
#     subActNum         room        activity                  concat  \
# 0         100     Bathroom   Toilet Flush     bathroom_toiletflush
# 1         101     Bathroom    Light switch    bathroom_lightswitch
# 2         104        Foyer    Light switch       foyer_lightswitch
# 3         105      Kitchen    Light switch     kitchen_lightswitch
# 4         106      Kitchen          Burner          kitchen_burner
# 5         107  Living room    Light switch  livingroom_lightswitch
# 6         108      Bedroom    Light switch     bedroom_lightswitch
# 7         109        Porch    Light switch       porch_lightswitch
# 8         118      Kitchen          Burner          kitchen_burner
# 9         119      Kitchen  Coffee machine   kitchen_coffeemachine
# 10        120      Kitchen    Light switch     kitchen_lightswitch
# 11        125      Kitchen          Drawer          kitchen_drawer
# 12        126      Kitchen    Refrigerator    kitchen_refrigerator
# 13        129      Kitchen            Oven            kitchen_oven
# 14        130     Bathroom            Door           bathroom_door
# 15        131      Kitchen         Toaster         kitchen_toaster
# 16        132      Kitchen         Cabinet         kitchen_cabinet
# 17        133      Kitchen         Cabinet         kitchen_cabinet
# 18        135      Kitchen          Drawer          kitchen_drawer
# 19        136      Kitchen          Window          kitchen_window
# 20        137      Kitchen         Freezer         kitchen_freezer
# 21        138      Kitchen         Cabinet         kitchen_cabinet
# 22        139      Bedroom     Jewelry box      bedroom_jewelrybox
# 23        140        Foyer            Door              foyer_door
# 24        141      Kitchen            Door            kitchen_door
#
#     reqElectricity  specialChar
# 0            False        False
# 1             True        False
# 2             True        False
# 3             True        False
# 4             True        False
# 5             True        False
# 6             True        False
# 7             True        False
# 8             True        False
# 9             True        False
# 10            True        False
# 11           False        False
# 12            True        False
# 13            True        False
# 14           False        False
# 15            True        False
# 16           False        False
# 17           False        False
# 18           False        False
# 19           False        False
# 20            True        False
# 21           False        False
# 22           False        False
# 23           False        False
# 24           False        False

# %%
dsS1Sensors[26:50]
# Out:
#     subActNum         room           activity                    concat  \
# 26        143      Kitchen          Microwave         kitchen_microwave
# 27        144      Kitchen       Refrigerator      kitchen_refrigerator
# 28        145      Kitchen             Cereal            kitchen_cereal
# 29        146      Bedroom             Drawer            bedroom_drawer
# 30         51      Kitchen            Cabinet           kitchen_cabinet
# 31         52      Kitchen             Drawer            kitchen_drawer
# 32         53      Kitchen            Cabinet           kitchen_cabinet
# 33         54      Kitchen               Door              kitchen_door
# 34         55      Kitchen            Cabinet           kitchen_cabinet
# 35         56  Living room               DVD             livingroom_dvd
# 36         57     Bathroom   Medicine cabinet  bathroom_medicinecabinet
# 37         58     Bathroom   Medicine cabinet  bathroom_medicinecabinet
# 38         59      Kitchen            Cabinet           kitchen_cabinet
# 39         60      Kitchen         Containers        kitchen_containers
# 40         61      Kitchen            Cabinet           kitchen_cabinet
# 41         62      Bedroom             Drawer            bedroom_drawer
# 42         63      Kitchen            Cabinet           kitchen_cabinet
# 43         64      Bedroom               Lamp              bedroom_lamp
# 44         66      Kitchen            Cabinet           kitchen_cabinet
# 45         67     Bathroom            Cabinet          bathroom_cabinet
# 46         68     Bathroom  Sink faucet - hot   bathroom_sinkfaucet-hot
# 47         69      Kitchen             Drawer            kitchen_drawer
# 48         70      Kitchen         Dishwasher        kitchen_dishwasher
# 49         71      Bedroom             Drawer            bedroom_drawer
#
#     reqElectricity  specialChar
# 26            True        False
# 27            True        False
# 28           False        False
# 29           False        False
# 30           False        False
# 31           False        False
# 32           False        False
# 33           False        False
# 34           False        False
# 35            True        False
# 36           False        False
# 37           False        False
# 38           False        False
# 39           False        False
# 40           False        False
# 41           False        False
# 42           False        False
# 43            True        False
# 44           False        False
# 45           False        False
# 46            True        False
# 47           False        False
# 48            True        False
# 49           False        False

# %%
dsS1Sensors[50:76]
# Out:
#     subActNum          room            activity                    concat  \
# 50         72       Kitchen             Cabinet           kitchen_cabinet
# 51         73       Kitchen             Cabinet           kitchen_cabinet
# 52         75       Bedroom              Drawer            bedroom_drawer
# 53         76   Living room                Lamp           livingroom_lamp
# 54         78       Kitchen              Drawer            kitchen_drawer
# 55         79      Bathroom             Cabinet          bathroom_cabinet
# 56         80       Kitchen             Cabinet           kitchen_cabinet
# 57         81         Foyer              Closet              foyer_closet
# 58         82  Office/study              Drawer       office/study_drawer
# 59         83       Kitchen             Cabinet           kitchen_cabinet
# 60         84       Kitchen              Drawer            kitchen_drawer
# 61         85       Bedroom              Window            bedroom_window
# 62         86       Bedroom              Drawer            bedroom_drawer
# 63         87       Kitchen              Drawer            kitchen_drawer
# 64         88      Bathroom  Sink faucet - cold  bathroom_sinkfaucet-cold
# 65         89       Kitchen             Cabinet           kitchen_cabinet
# 66         90       Kitchen       Laundry Dryer      kitchen_laundrydryer
# 67         91       Kitchen        Refrigerator      kitchen_refrigerator
# 68         92  Office/study        Light switch  office/study_lightswitch
# 69         93      Bathroom       Shower faucet     bathroom_showerfaucet
# 70         94       Kitchen              Burner            kitchen_burner
# 71         95       Kitchen        Light switch       kitchen_lightswitch
# 72         96      Bathroom         Exhaust Fan       bathroom_exhaustfan
# 73         97   Living room        Light switch    livingroom_lightswitch
# 74         98       Kitchen    Garbage disposal   kitchen_garbagedisposal
# 75         99       Kitchen              Burner            kitchen_burner
#
#     reqElectricity  specialChar
# 50           False        False
# 51           False        False
# 52           False        False
# 53            True        False
# 54           False        False
# 55           False        False
# 56           False        False
# 57           False        False
# 58           False         True
# 59           False        False
# 60           False        False
# 61           False        False
# 62           False        False
# 63           False        False
# 64           False        False
# 65           False        False
# 66            True        False
# 67            True        False
# 68            True         True
# 69           False        False
# 70            True        False
# 71            True        False
# 72            True        False
# 73            True        False
# 74            True        False
# 75            True        False

# %% [markdown]
# Comment: Later the ## values for subActNum will become subActNum_##

# %%
dsS1Sensors['subActNumConcat'] = 'subActNum_' + dsS1Sensors['subActNum'].astype(str)

# %%
dsS1Sensors[0:10]
# Out:
#    subActNum         room        activity                  concat  \
# 0        100     Bathroom   Toilet Flush     bathroom_toiletflush
# 1        101     Bathroom    Light switch    bathroom_lightswitch
# 2        104        Foyer    Light switch       foyer_lightswitch
# 3        105      Kitchen    Light switch     kitchen_lightswitch
# 4        106      Kitchen          Burner          kitchen_burner
# 5        107  Living room    Light switch  livingroom_lightswitch
# 6        108      Bedroom    Light switch     bedroom_lightswitch
# 7        109        Porch    Light switch       porch_lightswitch
# 8        118      Kitchen          Burner          kitchen_burner
# 9        119      Kitchen  Coffee machine   kitchen_coffeemachine
#
#    reqElectricity subActNumConcat
# 0           False   subActNum_100
# 1            True   subActNum_101
# 2            True   subActNum_104
# 3            True   subActNum_105
# 4            True   subActNum_106
# 5            True   subActNum_107
# 6            True   subActNum_108
# 7            True   subActNum_109
# 8            True   subActNum_118
# 9            True   subActNum_119

# %%
subActKeyWithStringDict = pd.Series(dsS1Sensors.concat.values, dsS1Sensors.subActNumConcat.values).to_dict()
subActKeyWithStringDict
# Out:
# {'subActNum_100': 'bathroom_toiletflush',
#  'subActNum_101': 'bathroom_lightswitch',
#  'subActNum_104': 'foyer_lightswitch',
#  'subActNum_105': 'kitchen_lightswitch',
#  'subActNum_106': 'kitchen_burner',
#  'subActNum_107': 'livingroom_lightswitch',
#  'subActNum_108': 'bedroom_lightswitch',
#  'subActNum_109': 'porch_lightswitch',
#  'subActNum_118': 'kitchen_burner',
#  'subActNum_119': 'kitchen_coffeemachine',
#  'subActNum_120': 'kitchen_lightswitch',
#  'subActNum_125': 'kitchen_drawer',
#  'subActNum_126': 'kitchen_refrigerator',
#  'subActNum_129': 'kitchen_oven',
#  'subActNum_130': 'bathroom_door',
#  'subActNum_131': 'kitchen_toaster',
#  'subActNum_132': 'kitchen_cabinet',
#  'subActNum_133': 'kitchen_cabinet',
#  'subActNum_135': 'kitchen_drawer',
#  'subActNum_136': 'kitchen_window',
#  'subActNum_137': 'kitchen_freezer',
#  'subActNum_138': 'kitchen_cabinet',
#  'subActNum_139': 'bedroom_jewelrybox',
#  'subActNum_140': 'foyer_door',
#  'subActNum_141': 'kitchen_door',
#  'subActNum_142': 'kitchen_washingmachine',
#  'subActNum_143': 'kitchen_microwave',
#  'subActNum_144': 'kitchen_refrigerator',
#  'subActNum_145': 'kitchen_cereal',
#  'subActNum_146': 'bedroom_drawer',
#  'subActNum_51': 'kitchen_cabinet',
#  'subActNum_52': 'kitchen_drawer',
#  'subActNum_53': 'kitchen_cabinet',
#  'subActNum_54': 'kitchen_door',
#  'subActNum_55': 'kitchen_cabinet',
#  'subActNum_56': 'livingroom_dvd',
#  'subActNum_57': 'bathroom_medicinecabinet',
#  'subActNum_58': 'bathroom_medicinecabinet',
#  'subActNum_59': 'kitchen_cabinet',
#  'subActNum_60': 'kitchen_containers',
#  'subActNum_61': 'kitchen_cabinet',
#  'subActNum_62': 'bedroom_drawer',
#  'subActNum_63': 'kitchen_cabinet',
#  'subActNum_64': 'bedroom_lamp',
#  'subActNum_66': 'kitchen_cabinet',
#  'subActNum_67': 'bathroom_cabinet',
#  'subActNum_68': 'bathroom_sinkfaucet-hot',
#  'subActNum_69': 'kitchen_drawer',
#  'subActNum_70': 'kitchen_dishwasher',
#  'subActNum_71': 'bedroom_drawer',
#  'subActNum_72': 'kitchen_cabinet',
#  'subActNum_73': 'kitchen_cabinet',
#  'subActNum_75': 'bedroom_drawer',
#  'subActNum_76': 'livingroom_lamp',
#  'subActNum_78': 'kitchen_drawer',
#  'subActNum_79': 'bathroom_cabinet',
#  'subActNum_80': 'kitchen_cabinet',
#  'subActNum_81': 'foyer_closet',
#  'subActNum_82': 'office/study_drawer',
#  'subActNum_83': 'kitchen_cabinet',
#  'subActNum_84': 'kitchen_drawer',
#  'subActNum_85': 'bedroom_window',
#  'subActNum_86': 'bedroom_drawer',
#  'subActNum_87': 'kitchen_drawer',
#  'subActNum_88': 'bathroom_sinkfaucet-cold',
#  'subActNum_89': 'kitchen_cabinet',
#  'subActNum_90': 'kitchen_laundrydryer',
#  'subActNum_91': 'kitchen_refrigerator',
#  'subActNum_92': 'office/study_lightswitch',
#  'subActNum_93': 'bathroom_showerfaucet',
#  'subActNum_94': 'kitchen_burner',
#  'subActNum_95': 'kitchen_lightswitch',
#  'subActNum_96': 'bathroom_exhaustfan',
#  'subActNum_97': 'livingroom_lightswitch',
#  'subActNum_98': 'kitchen_garbagedisposal',
#  'subActNum_99': 'kitchen_burner'}

# %%
subActKeyWithEnergyDict = pd.Series(dsS1Sensors.reqElectricity.values, 
                                    dsS1Sensors.subActNumConcat.values).to_dict()
print(subActKeyWithEnergyDict['subActNum_100'],    # Checking the dictionary
      subActKeyWithEnergyDict['subActNum_101'])
# Out:
# False True

# %%
seen = {}
dupes = []

for x in dsS1Sensors.concat:
    if x not in seen:
        seen[x] = 1
    else:
        if seen[x] == 1:
            dupes.append(x)
        seen[x] += 1

# %%
for i in seen:                  # Adding value counts for dupes
    if (seen[i] > 1 and seen[i] <= 9):
        print(seen[i], " ", i)
    if (seen[i] >= 10):
        print(seen[i], "", i)
# Out:
# 3   kitchen_lightswitch
# 4   kitchen_burner
# 2   livingroom_lightswitch
# 7   kitchen_drawer
# 3   kitchen_refrigerator
# 15  kitchen_cabinet
# 2   kitchen_door
# 5   bedroom_drawer
# 2   bathroom_medicinecabinet
# 2   bathroom_cabinet

# %%
dsS1Sensors.to_csv('S1Sensors_preprocessed.csv',index = False)

# %%
# FIX OFFICE/STUDY

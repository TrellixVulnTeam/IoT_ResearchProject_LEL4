# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import feature_selection as fs
from sklearn.model_selection import RepeatedStratifiedKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
import datetime as dt

df = pd.read_csv('S1SubAct_B_m_NoDupes.csv', index_col = "duration")
df.reset_index(drop = True, inplace = True)

df_sensors = pd.read_csv('S1Sensors_preprocessed.csv', index_col = None)
df_sensors = df_sensors[df_sensors.reqEnergy]

df_costs = pd.read_csv('power_costs.csv', index_col = None)

def add_DAY_WDWE_phaseII(ds):
    dayNumKeyWithDAYDict = pd.Series(['Mon','Tue','Wed','Thu','Fri','Sat','Sun'], ['0','1','2','3','4','5','6']).to_dict()
    dayNumKeyWithWDWEDict = pd.Series(['WD','WD','WD','WD','WD','WE','WE'], ['0','1','2','3','4','5','6']).to_dict()
    ds.set_index(ds['timestamp'], inplace = True)
    ds.insert((len(ds.columns)), "DAY", ds.index.dayofweek.astype(str), True)
    ds.insert((len(ds.columns)), "WDWE", ds.index.dayofweek.astype(str), True)
    ds = ds.replace({"DAY": dayNumKeyWithDAYDict})
    ds = ds.replace({"WDWE": dayNumKeyWithWDWEDict})
    ds.reset_index(drop = True, inplace = True)
    ds['Hour'] = ds['timestamp'].dt.hour
    return ds

# %%
ds = pd.read_csv('S1SubActivities_temporalFeaturesCLEANSED.csv', index_col = None) 
ds.start = pd.to_datetime(ds.start, format='%Y-%m-%d %H:%M:%S')
ds.end = pd.to_datetime(ds.end, format='%Y-%m-%d %H:%M:%S')

# %%
ds_new = ds.copy()
ds_new['Phase'] = "Afternoon"
ds_new.loc[ds_new['HOUR'] < 12, 'Phase'] = "Morning"
ds_new.loc[ds_new['HOUR'] >= 18, 'Phase'] = "Evening"
benchmark_usage = ds_new.groupby(['subAct','WDWE','Phase'])['durationSec'].mean()

# %%
def calc_subAct(dataframe, subAct, wattage, df_costs):
    
    df = dataframe.copy()

    Data = df.drop(columns = subAct).values
    target = df[subAct]
    D_train, D_test, t_train, t_test = train_test_split(Data, target, test_size = 0.3,
                                                        random_state=999)
    dt_classifier = DecisionTreeClassifier(max_depth=10, criterion='entropy',
                                           random_state = 999)
    dt_classifier.fit(D_train, t_train)
    confidence = dt_classifier.score(D_test, t_test)
    df['prediction'] = dt_classifier.predict(Data)
    df['intervention'] = (df['prediction'].diff() == -1) & (df[subAct] == 1)
    
    dfIDX = pd.read_csv('S1SubAct_B_m_NoDupes.csv', index_col = None)
    dfIDX.duration = pd.to_datetime(dfIDX.duration, format='%Y-%m-%d %H:%M:%S')
    df['timestamp'] = dfIDX['duration']

    df = add_DAY_WDWE_phaseII(df)
    df['Phase'] = "Afternoon"
    df.loc[df['Hour'] < 12, 'Phase'] = "Morning"
    df.loc[df['Hour'] >= 18, 'Phase'] = "Evening"
    
    # Calculate approx durations
    duration = 0
    duration_col = []

    for row in df.iterrows():
        if row[1][subAct] == 1:
            duration += 1
        else:
            duration = 0
        duration_col.append(duration)

    df['duration'] = duration_col

    cancelled_interventions = 0
    completed_interventions = 0
    possible_intervention = False
    intervening = False

    total_minutes_saved = 0
    total_kwh_saved = 0
    total_dollars_saved = 0

    for row in df.iterrows():
        if row[1]['intervention'] and not intervening:
            possible_intervention = True
        if possible_intervention:
            if row[1][subAct] == 0:
                possible_intervention = False
                cancelled_interventions += 1
            else:
                if row[1]['duration'] > benchmark_usage[subAct][row[1]['WDWE']][row[1]['Phase']] / 60:
                    intervening = True
                    completed_interventions += 1
                    possible_intervention = False
        if intervening:
            if row[1][subAct] == 0:
                intervening = False
            else:
                total_minutes_saved += 1
                kwh_saved = wattage / 60 / 1000
                total_kwh_saved += kwh_saved
                hour = row[1]['Hour']
                wdwe = row[1]['WDWE']
                rate = df_costs[(df_costs['Hour'] == hour) & (df_costs['WDWE'] == wdwe)].iloc[0]['cost_per_kwh']
                dollars_saved = rate * kwh_saved
                total_dollars_saved += dollars_saved

    # Note that this means our 'confidence' value is going to be more conservative than it needs to be
    print("SubAct:",subAct)
    print("Classifier confidence:", round(confidence,3))
    print("Number of completed interventions:", completed_interventions)
    print("Number of interventions cancelled due to not meeting average number of minutes usage:", 
          cancelled_interventions)
    print("Total minutes saved:", round(total_minutes_saved, 3))
    print("Total minutes saved, accounting for confidence:", round(total_minutes_saved * confidence,3))
    print("Total electricity saved (kwh):", round(total_kwh_saved,3))
    print("Total electricity saved, accounting for confidence (kwh):", round(total_kwh_saved * confidence,3))
    print("Total money saved: $", round(total_dollars_saved,3))
    print("Total money saved accounting for confidence:  $", round(total_dollars_saved * confidence,3))
    print()
    

for row in df_sensors.iterrows():
    subAct = row[1]['concat']
    wattage = row[1]['wattage']
    calc_subAct(df, subAct, wattage, df_costs)
# Out:
# SubAct: bathroom_lightswitch
# Classifier confidence: 0.847
# Number of completed interventions: 11
# Number of interventions cancelled due to not meeting average number of minutes usage: 12
# Total minutes saved: 420
# Total minutes saved, accounting for confidence: 355.914
# Total electricity saved (kwh): 0.168
# Total electricity saved, accounting for confidence (kwh): 0.142
# Total money saved: $ 0.039
# Total money saved accounting for confidence:  $ 0.033
#
# SubAct: foyer_lightswitch
# Classifier confidence: 0.992
# Number of completed interventions: 0
# Number of interventions cancelled due to not meeting average number of minutes usage: 1
# Total minutes saved: 0
# Total minutes saved, accounting for confidence: 0.0
# Total electricity saved (kwh): 0
# Total electricity saved, accounting for confidence (kwh): 0.0
# Total money saved: $ 0
# Total money saved accounting for confidence:  $ 0.0
#
# SubAct: kitchen_lightswitch
# Classifier confidence: 0.805
# Number of completed interventions: 12
# Number of interventions cancelled due to not meeting average number of minutes usage: 6
# Total minutes saved: 440
# Total minutes saved, accounting for confidence: 354.275
# Total electricity saved (kwh): 0.352
# Total electricity saved, accounting for confidence (kwh): 0.283
# Total money saved: $ 0.086
# Total money saved accounting for confidence:  $ 0.069
#
# SubAct: kitchen_burner
# Classifier confidence: 0.965
# Number of completed interventions: 5
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 50
# Total minutes saved, accounting for confidence: 48.266
# Total electricity saved (kwh): 1.25
# Total electricity saved, accounting for confidence (kwh): 1.207
# Total money saved: $ 0.29
# Total money saved accounting for confidence:  $ 0.28
#
# SubAct: livingroom_lightswitch
# Classifier confidence: 0.904
# Number of completed interventions: 3
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 21
# Total minutes saved, accounting for confidence: 18.987
# Total electricity saved (kwh): 0.017
# Total electricity saved, accounting for confidence (kwh): 0.015
# Total money saved: $ 0.004
# Total money saved accounting for confidence:  $ 0.003
#
# SubAct: bedroom_lightswitch
# Classifier confidence: 0.979
# Number of completed interventions: 2
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 7
# Total minutes saved, accounting for confidence: 6.85
# Total electricity saved (kwh): 0.004
# Total electricity saved, accounting for confidence (kwh): 0.004
# Total money saved: $ 0.001
# Total money saved accounting for confidence:  $ 0.001
#
# SubAct: kitchen_coffeemachine
# Classifier confidence: 0.998
# Number of completed interventions: 0
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 0
# Total minutes saved, accounting for confidence: 0.0
# Total electricity saved (kwh): 0
# Total electricity saved, accounting for confidence (kwh): 0.0
# Total money saved: $ 0
# Total money saved accounting for confidence:  $ 0.0
#
# SubAct: kitchen_refrigerator
# Classifier confidence: 0.961
# Number of completed interventions: 8
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 51
# Total minutes saved, accounting for confidence: 49.006
# Total electricity saved (kwh): 0.128
# Total electricity saved, accounting for confidence (kwh): 0.123
# Total money saved: $ 0.028
# Total money saved accounting for confidence:  $ 0.027
#
# SubAct: kitchen_oven
# Classifier confidence: 0.994
# Number of completed interventions: 0
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 0
# Total minutes saved, accounting for confidence: 0.0
# Total electricity saved (kwh): 0
# Total electricity saved, accounting for confidence (kwh): 0.0
# Total money saved: $ 0
# Total money saved accounting for confidence:  $ 0.0
#
# SubAct: kitchen_toaster
# Classifier confidence: 0.989
# Number of completed interventions: 1
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 1
# Total minutes saved, accounting for confidence: 0.989
# Total electricity saved (kwh): 0.016
# Total electricity saved, accounting for confidence (kwh): 0.016
# Total money saved: $ 0.003
# Total money saved accounting for confidence:  $ 0.003
#
# SubAct: kitchen_freezer
# Classifier confidence: 0.924
# Number of completed interventions: 22
# Number of interventions cancelled due to not meeting average number of minutes usage: 7
# Total minutes saved: 249
# Total minutes saved, accounting for confidence: 230.003
# Total electricity saved (kwh): 0.622
# Total electricity saved, accounting for confidence (kwh): 0.575
# Total money saved: $ 0.145
# Total money saved accounting for confidence:  $ 0.134
#
# SubAct: kitchen_washingmachine
# Classifier confidence: 0.982
# Number of completed interventions: 6
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 11
# Total minutes saved, accounting for confidence: 10.799
# Total electricity saved (kwh): 0.403
# Total electricity saved, accounting for confidence (kwh): 0.396
# Total money saved: $ 0.089
# Total money saved accounting for confidence:  $ 0.087
#
# SubAct: kitchen_microwave
# Classifier confidence: 0.987
# Number of completed interventions: 0
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 0
# Total minutes saved, accounting for confidence: 0.0
# Total electricity saved (kwh): 0
# Total electricity saved, accounting for confidence (kwh): 0.0
# Total money saved: $ 0
# Total money saved accounting for confidence:  $ 0.0
#
# SubAct: bathroom_sinkfaucet-hot
# Classifier confidence: 0.975
# Number of completed interventions: 14
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 17
# Total minutes saved, accounting for confidence: 16.582
# Total electricity saved (kwh): 5.497
# Total electricity saved, accounting for confidence (kwh): 5.362
# Total money saved: $ 1.261
# Total money saved accounting for confidence:  $ 1.23
#
# SubAct: kitchen_dishwasher
# Classifier confidence: 0.955
# Number of completed interventions: 9
# Number of interventions cancelled due to not meeting average number of minutes usage: 1
# Total minutes saved: 106
# Total minutes saved, accounting for confidence: 101.255
# Total electricity saved (kwh): 3.887
# Total electricity saved, accounting for confidence (kwh): 3.713
# Total money saved: $ 0.855
# Total money saved accounting for confidence:  $ 0.817
#
# SubAct: livingroom_lamp
# Classifier confidence: 0.804
# Number of completed interventions: 2
# Number of interventions cancelled due to not meeting average number of minutes usage: 1
# Total minutes saved: 570
# Total minutes saved, accounting for confidence: 458.228
# Total electricity saved (kwh): 0.114
# Total electricity saved, accounting for confidence (kwh): 0.092
# Total money saved: $ 0.027
# Total money saved accounting for confidence:  $ 0.021
#
# SubAct: kitchen_laundrydryer
# Classifier confidence: 0.985
# Number of completed interventions: 5
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 12
# Total minutes saved, accounting for confidence: 11.826
# Total electricity saved (kwh): 0.6
# Total electricity saved, accounting for confidence (kwh): 0.591
# Total money saved: $ 0.134
# Total money saved accounting for confidence:  $ 0.132
#
# SubAct: study_lightwitch
# Classifier confidence: 0.885
# Number of completed interventions: 4
# Number of interventions cancelled due to not meeting average number of minutes usage: 3
# Total minutes saved: 39
# Total minutes saved, accounting for confidence: 34.525
# Total electricity saved (kwh): 0.023
# Total electricity saved, accounting for confidence (kwh): 0.021
# Total money saved: $ 0.006
# Total money saved accounting for confidence:  $ 0.005
#
# SubAct: bathroom_showerfaucet
# Classifier confidence: 0.959
# Number of completed interventions: 7
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 49
# Total minutes saved, accounting for confidence: 46.992
# Total electricity saved (kwh): 15.843
# Total electricity saved, accounting for confidence (kwh): 15.194
# Total money saved: $ 3.524
# Total money saved accounting for confidence:  $ 3.38
#
# SubAct: bathroom_exhaustfan
# Classifier confidence: 0.875
# Number of completed interventions: 5
# Number of interventions cancelled due to not meeting average number of minutes usage: 2
# Total minutes saved: 24
# Total minutes saved, accounting for confidence: 21.004
# Total electricity saved (kwh): 0.024
# Total electricity saved, accounting for confidence (kwh): 0.021
# Total money saved: $ 0.005
# Total money saved accounting for confidence:  $ 0.005
#
# SubAct: kitchen_garbagedisposal
# Classifier confidence: 0.997
# Number of completed interventions: 0
# Number of interventions cancelled due to not meeting average number of minutes usage: 0
# Total minutes saved: 0
# Total minutes saved, accounting for confidence: 0.0
# Total electricity saved (kwh): 0
# Total electricity saved, accounting for confidence (kwh): 0.0
# Total money saved: $ 0
# Total money saved accounting for confidence:  $ 0.0
